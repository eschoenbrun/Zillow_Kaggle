# %%
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('data/train-ml.csv')

# %%
def reduce_mem_usage(props):
    start_mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage of properties dataframe is :",start_mem_usg," MB")
    NAlist = [] # Keeps track of columns that have missing values filled in. 
    for col in props.columns:
        if props[col].dtype != object:  # Exclude strings
            
            # Print current column type
            print("******************************")
            print("Column: ",col)
            print("dtype before: ",props[col].dtype)
            
            # make variables for Int, max and min
            IsInt = False
            mx = props[col].max()
            mn = props[col].min()
            
            # Integer does not support NA, therefore, NA needs to be filled
            if not np.isfinite(props[col]).all(): 
                NAlist.append(col)
                props[col].fillna(mn-1,inplace=True)  
                   
            # test if column can be converted to an integer
            asint = props[col].fillna(0).astype(np.int64)
            result = (props[col] - asint)
            result = result.sum()
            if result > -0.01 and result < 0.01:
                IsInt = True

            
            # Make Integer/unsigned Integer datatypes
            if IsInt:
                if mn >= 0:
                    if mx < 255:
                        props[col] = props[col].astype(np.uint8)
                    elif mx < 65535:
                        props[col] = props[col].astype(np.uint16)
                    elif mx < 4294967295:
                        props[col] = props[col].astype(np.uint32)
                    else:
                        props[col] = props[col].astype(np.uint64)
                else:
                    if mn > np.iinfo(np.int8).min and mx < np.iinfo(np.int8).max:
                        props[col] = props[col].astype(np.int8)
                    elif mn > np.iinfo(np.int16).min and mx < np.iinfo(np.int16).max:
                        props[col] = props[col].astype(np.int16)
                    elif mn > np.iinfo(np.int32).min and mx < np.iinfo(np.int32).max:
                        props[col] = props[col].astype(np.int32)
                    elif mn > np.iinfo(np.int64).min and mx < np.iinfo(np.int64).max:
                        props[col] = props[col].astype(np.int64)    
            
            # Make float datatypes 32 bit
            else:
                props[col] = props[col].astype(np.float32)
            
            # Print new column type
            print("dtype after: ",props[col].dtype)
            print("******************************")
    
    # Print final result
    print("___MEMORY USAGE AFTER COMPLETION:___")
    mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage is: ",mem_usg," MB")
    print("This is ",100*mem_usg/start_mem_usg,"% of the initial size")
    return props, NAlist

# %%
props, NAlist = reduce_mem_usage(df)
# Out:
# Memory usage of properties dataframe is : 13.423698425292969  MB
# ******************************
# Column:  taxvaluedollarcnt
# dtype before:  float64
# dtype after:  uint32
# ******************************
# ******************************
# Column:  taxdelinquencyyear
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  latitude
# dtype before:  float64
# dtype after:  uint32
# ******************************
# ******************************
# Column:  yearbuilt
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  transaction_mth
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  unitcnt
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  taxamount
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  lotsizesquarefeet
# dtype before:  float64
# dtype after:  uint32
# ******************************
# ******************************
# Column:  calculatedfinishedsquarefeet
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  transaction_yr
# dtype before:  float64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  transaction_day_of_wk
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  structuretaxvaluedollarcnt
# dtype before:  float64
# dtype after:  uint32
# ******************************
# ******************************
# Column:  fullbathcnt
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  landtaxvaluedollarcnt
# dtype before:  float64
# dtype after:  uint32
# ******************************
# ******************************
# Column:  longitude
# dtype before:  float64
# dtype after:  int32
# ******************************
# ******************************
# Column:  roomcnt
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  bedroomcnt
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  bathroomcnt
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  propertylandusetypeid_246.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid_247.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid_248.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid_260.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid_261.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid_263.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid_264.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid_265.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid_266.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid_267.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid_269.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid_275.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertylandusetypeid_31.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  taxdelinquencyflag_Y
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  taxdelinquencyflag_no
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  heatingorsystemtypeid_1.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  heatingorsystemtypeid_10.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  heatingorsystemtypeid_13.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  heatingorsystemtypeid_18.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  heatingorsystemtypeid_2.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  heatingorsystemtypeid_20.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  heatingorsystemtypeid_24.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  heatingorsystemtypeid_6.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  heatingorsystemtypeid_7.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hashottuborspa_0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  pooltypeid10_0.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  pooltypeid10_1.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  architecturalstyletypeid_2.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  architecturalstyletypeid_21.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  architecturalstyletypeid_7.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  architecturalstyletypeid_8.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  pooltypeid7_0.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  pooltypeid7_1.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_1.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_10.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_11.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_12.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_2.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_3.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_4.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_5.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_6.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_7.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_8.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  buildingqualitytypeid_9.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  typeconstructiontypeid_0.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  typeconstructiontypeid_6.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  decktypeid_0.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  decktypeid_66.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  airconditioningtypeid_1.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  airconditioningtypeid_11.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  airconditioningtypeid_13.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  airconditioningtypeid_5.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  airconditioningtypeid_9.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  pooltypeid2_0.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  pooltypeid2_1.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  fips_6037.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  fips_6059.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  fips_6111.0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0100
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0101
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0102
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0103
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0104
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0108
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0109
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_010C
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_010D
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_010E
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_010F
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_010G
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_010H
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_010M
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_010V
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0110
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0111
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0113
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0115
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_012C
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_012D
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_012E
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_01DC
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_01HC
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_01HE
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0200
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0201
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0300
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0400
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_0700
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_070D
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_100V
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1014
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_105
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1110
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1111
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1112
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1116
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1117
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1128
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1129
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1210
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_122
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1222
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1310
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_135
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_1410
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_34
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_38
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_73
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  propertycountylandusecode_96
# dtype before:  float64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  logerror
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  2.06229305267334  MB
# This is  15.36307645877653 % of the initial size

# %%
df_sample1 = df[['propertycountylandusecode_38', 'propertylandusetypeid_248.0', 'pooltypeid10_0.0', 'propertycountylandusecode_01HC', 'propertycountylandusecode_1', 'buildingqualitytypeid_9.0', 'typeconstructiontypeid_0.0', 'propertycountylandusecode_34', 'propertycountylandusecode_0200', 'taxdelinquencyflag_Y', 'buildingqualitytypeid_8.0', 'propertycountylandusecode_010E', 'propertycountylandusecode_0101', 'taxdelinquencyyear', 'propertylandusetypeid_266.0', 'pooltypeid2_0.0', 'transaction_yr', 'fips_6059.0', 'unitcnt', 'bathroomcnt', 'buildingqualitytypeid_6.0', 'airconditioningtypeid_1.0', 'heatingorsystemtypeid_7.0', 'transaction_day_of_wk', 'bedroomcnt', 'roomcnt', 'yearbuilt', 'calculatedfinishedsquarefeet', 'taxamount', 'taxvaluedollarcnt', 'landtaxvaluedollarcnt', 'structuretaxvaluedollarcnt', 'latitude', 'lotsizesquarefeet', 'longitude', 'pooltypeid10_1.0', 'typeconstructiontypeid_6.0', 'pooltypeid2_1.0', 'taxdelinquencyflag_no', 'logerror']]

# %%
len(df_sample1)
# Out:
# 13431

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df_sample1,test_size=0.2, random_state=4)

# %%
X_train = train.drop('logerror', axis=1).values
y_train = train['logerror'].values

# %%
len(X_train), len(y_train)
# Out:
# (10744, 10744)

# %%
from sklearn.metrics import mean_absolute_error

# %%
rf = RandomForestRegressor(criterion='mae',n_jobs=-1)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mae', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=-1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
X_test = test.drop('logerror',axis=1).values
y_test = test['logerror'].values

# %%
y_preds = rf.predict(X_test)

# %%
len(y_preds)
# Out:
# 2687

# %%
ys = rf.predict(X_train)

# %%
mean_absolute_error(y_test, y_preds)
# Out:
# 0.084207073958967663

# %%
num_splits = 10
seed = 7

# %%
kfold = model_selection.KFold(n_splits = num_splits, random_state=seed)

# %%
model = RandomForestRegressor(criterion='mae')

# %%
results = model_selection.cross_val_score(model, data, target, cv=num_splits,
                                          n_jobs=-1,scoring='neg_mean_absolute_error')

# %%
results.mean()
# Out:
# -0.088577886290800587

# %%
results
# Out:
# array([-0.09519925, -0.09184664, -0.08757733, -0.0993521 , -0.07764035,
#        -0.08395402, -0.08728465, -0.09514591, -0.08713768, -0.08064094])
